# %% [markdown]
# # 1. Dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)

# %%
import os
import gym
from stable_baselines3 import PPO
# Wrapper for the env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load the Environment

# %%
env_name = 'CartPole-v0'
env = gym.make(env_name)

# %%
episodes = 10

for episode in range(1, episodes+1):
    # Initial set of observations
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode {}, Score: {}'.format(episode, score))
env.close()
# Out:
# Episode 1, Score: 19.0
# Episode 2, Score: 35.0
# Episode 3, Score: 15.0
# Episode 4, Score: 21.0
# Episode 5, Score: 13.0
# Episode 6, Score: 31.0
# Episode 7, Score: 13.0
# Episode 8, Score: 15.0
# Episode 9, Score: 19.0
# Episode 10, Score: 31.0

# %%
env.reset()
# Out:
# array([-0.00054234, -0.03056862,  0.02416388, -0.02822847], dtype=float32)

# %%
# Two actions: 0 or 1
env.action_space
# Out:
# Discrete(2)

# %%
# Generating a random action
env.action_space.sample()
# Out:
# 0

# %%
# What the observations look like in that env
# First position: Cart position
# Second position: Cart velocity
# Third position: Pole angle
# Fourth position: Pole angular velocity
# Action 0: Push cart to the left
# Action 1: Push cart to the right
# However, documentation is not always provided for other simulated env
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
# An example of the observation space
env.observation_space.sample()
# Out:
# array([-2.1408737e+00,  2.4124330e+38,  2.8470987e-01,  2.9319986e+38],
#       dtype=float32)

# %%
# Our next set of observations from the observation space
env.step(1)
# Out:
# (array([ 0.16893412,  1.9234287 , -0.24574418, -3.0881803 ], dtype=float32),
#  1.0,
#  True,
#  {})

# %% [markdown]
# # 3. Training the Model

# %%
# Create the directories first manually
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
PPO?

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 970  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009278483 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.961       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00764    |
# ...

# %% [markdown]
# # 4. Saving and Reloading the Model

# %%
PPO_PATH = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_PATH)

# %%
# Reloading from saved model each time
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Reloading from saved model each time
# ----> 2 del model
#
# NameError: name 'model' is not defined

# %%
model = PPO.load(PPO_PATH, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    fps             | 942      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.4       |
# |    ep_rew_mean          | 26.4       |
# | time/                   |            |
# |    fps                  | 665        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00846014 |
# |    clip_fraction        | 0.0843     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# ...

# %% [markdown]
# # 5. Evaluation

# %%
# Evaluate policy tells us how well our policy is performing
# Cannot visualize on Colab so set render to False there
# Avg score, std deviation
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\yacoo\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (9.5, 0.6708203932499369)

# %%
env.close()

# %% [markdown]
# # 6. Testing the Model

# %%
# '_' is the states
action, _ = model.predict(obs)

# %%
action
# Out:
# array(1, dtype=int64)

# %%
env.step(action)
# Out:
# (array([-0.01145506, -0.00568984,  0.01421611,  0.04130784], dtype=float32),
#  1.0,
#  False,
#  {})

# %%
episodes = 5

for episode in range(1, episodes+1):
    # Initial set of observations
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        # Rather than taking random steps, the model will be taking steps based on what gets the best maximized reward
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode {}, Score: {}'.format(episode, score))
env.close()
# Out:
# Episode 1, Score: 20.0
# Episode 2, Score: 23.0
# Episode 3, Score: 16.0
# Episode 4, Score: 26.0
# Episode 5, Score: 16.0

# %%
env.close()

# %% [markdown]
# # 7. Logs in Tensorboard

# %%
# Can run this from cmd prompt as well as in here
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
# !pip install tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yacoo\appdata\roaming\python\python310\site-packages)

# %%
# '!' run commands onto the cmd prompt
# !python -m tensorboard.main --logdir={training_log_path} --port=6006
# Out:
# ^C

# %% [markdown]
# # 8. Callback for the Training

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, best_model_save_path=save_path, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    fps             | 1026     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.6        |
# |    ep_rew_mean          | 26.6        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009474982 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# ...

# %% [markdown]
# # 9. Changing Policies

# %%
# Pi: Neural network for our custom actor
# Each layer has 128 units
net_arch = dict(pi=[128,128,128,128], vf=[128,128,128,128])

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    fps             | 659      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34          |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013746284 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# ...

# %% [markdown]
# # 10. Alternate Algorithm(s)

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1899     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 153      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# ...

# %%
#DQN.load()
